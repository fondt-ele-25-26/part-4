# %% [markdown]
# ## Esercizio: Somma Elementi Speculari
#
# **Si scriva un programma che calcoli la lista con la somma degli elementi speculari in una lista di input**
#
# * Data una lista di ingresso `l`, contenente _un numero pari_ di elementi
# * ...Il programma deve calcolare una lista con i valori delle somme degli elementi in posizione speculare in `l`
# * ...Ossia il primo elemento con l'ultimo, il secondo con il penultimo e così via
#
# Per esempio, data la lista di ingresso:
#
# ```python
# l = [1, 3, 1, 4, 6, 9]
# ```
#
# Il programma deve calcolare la lista:
#
# ```python
# [10, 9, 5]
# ```
#
# Dove:
#
# * 10 = 1 + 9
# * 9  = 3 + 6
# * etc.
#
# Si stampi la lista risultante

# %% [markdown]
# ## Esercizio: Somma Elementi Speculari
#
# **Di seguito una possibile soluzione**

# %%
# Dati del problema
l = [1, 3, 1, 4, 6, 9]
